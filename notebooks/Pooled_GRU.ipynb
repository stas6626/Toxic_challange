# %%
import numpy as np
np.random.seed(42)
import pandas as pd
import re
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.metrics import roc_auc_score

from keras.optimizers import Adam
from keras.models import Model
from keras.layers import Input, Dense, Embedding, SpatialDropout1D, concatenate
from keras.layers import GRU, Bidirectional, GlobalAveragePooling1D, GlobalMaxPooling1D, CuDNNGRU
from keras.preprocessing import text, sequence
from keras.callbacks import Callback, ModelCheckpoint, EarlyStopping
from keras import backend as K

import os
os.environ['OMP_NUM_THREADS'] = '16'

import warnings
warnings.filterwarnings('ignore')

EMBEDDING_FILE = './data/glove.42B.300d.txt'

train = pd.read_csv('./data/train.csv.zip')
test = pd.read_csv('./data/test.csv.zip')
submission = pd.read_csv('./data/sample_submission.csv.zip')

X_train = train["comment_text"].fillna("fillna").values
y_train = train[["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]].values
X_test = test["comment_text"].fillna("fillna").values
# Out:
# /media/stas/fastdata/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
max_features = 30000
maxlen = 100
embed_size = 300

tokenizer = text.Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(list(X_train) + list(X_test))
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)
x_train = sequence.pad_sequences(X_train, maxlen=maxlen)
x_test = sequence.pad_sequences(X_test, maxlen=maxlen)

# %%
def get_coefs(word, *arr): return word, np.asarray(arr, dtype='float32')
embeddings_index = dict(get_coefs(*o.strip().split()) for o in open(EMBEDDING_FILE))

all_embs = np.stack(embeddings_index.values())
emb_mean, emb_std = all_embs.mean(), all_embs.std()

word_index = tokenizer.word_index
nb_words = min(max_features, len(word_index))
embedding_matrix = np.random.normal(emb_mean, emb_std, (nb_words, embed_size))
for word, i in word_index.items():
    if i >= max_features: continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None: embedding_matrix[i] = embedding_vector

# %%
class RocAucEvaluation(Callback):
    def __init__(self, validation_data=(), interval=1):
        super(Callback, self).__init__()

        self.interval = interval
        self.X_val, self.y_val = validation_data

    def on_epoch_end(self, epoch, logs={}):
        if epoch % self.interval == 0:
            y_pred = self.model.predict(self.X_val, verbose=0)
            score = roc_auc_score(self.y_val, y_pred)
            print("\n ROC-AUC - epoch: %d - score: %.6f \n" % (epoch+1, score))


def get_model():
    inp = Input(shape=(maxlen, ))
    x = Embedding(max_features, embed_size, weights=[embedding_matrix])(inp)
    x = SpatialDropout1D(0.4)(x)
    x = Bidirectional(CuDNNGRU(100, return_sequences=True))(x)
    x = SpatialDropout1D(0.5)(x)
    x = Bidirectional(CuDNNGRU(200, return_sequences=True))(x)
    x = SpatialDropout1D(0.4)(x)
    x = Bidirectional(CuDNNGRU(100, return_sequences=True))(x)
    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)
    conc = concatenate([avg_pool, max_pool])
    outp = Dense(6, activation="sigmoid")(conc)
    
    model = Model(inputs=inp, outputs=outp)
    adam = Adam(lr=0.0001, decay=0.000001)
    model.compile(loss='binary_crossentropy',
                  optimizer=adam,
                  metrics=['accuracy'])

    return model

# %%
#1.20

# %%
# %%time
gru_for_stack = pd.DataFrame.from_dict({'id': train['id'],
                                        "toxic":0,
                                        "severe_toxic":0,
                                        "obscene":0,
                                        "threat":0,
                                        "insult":0,
                                        "identity_hate":0})

batch_size = 1000
epochs = 20
cv = KFold(n_splits=5, random_state=0, shuffle=True)
i = 0

for train_index, test_index in cv.split(x_train, y_train):
    X_tra, X_test = x_train[train_index], x_train[test_index]
    y_tra, y_test = y_train[train_index], y_train[test_index]
    i += 1
    
    model = get_model()
    file_path=f"./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_{i}.best.hdf5"
    checkpoint = ModelCheckpoint(file_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

    early = EarlyStopping(monitor="val_loss", mode="min", patience=3)
    callbacks_list = [checkpoint, early] #early
    #exp_decay = lambda init, fin, steps: (init/fin)**(1/(steps-1)) - 1
    #steps = int(len(X_tra)/batch_size) * epochs
    #lr_init, lr_fin = 0.001, 0.0005
    #lr_decay = exp_decay(lr_init, lr_fin, steps)
    #K.set_value(model.optimizer.lr, lr_init)
    #K.set_value(model.optimizer.decay, lr_decay)

    hist = model.fit(X_tra, y_tra, batch_size=batch_size, epochs=epochs, callbacks=callbacks_list, validation_data=(X_test, y_test))

    model.load_weights(file_path)

    y_pred = model.predict(X_test, batch_size=1024)
    gru_for_stack.loc[test_index,["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]] = y_pred
gru_for_stack.to_csv('./submits/gru_100_0.4_200_0.5_100_0.4_stack_layer.csv', index=False)
# Out:
# Train on 127656 samples, validate on 31915 samples
# Epoch 1/20
# 127656/127656 [==============================] - 57s 448us/step - loss: 0.1365 - acc: 0.9572 - val_loss: 0.0611 - val_acc: 0.9780
#
# Epoch 00001: val_loss improved from inf to 0.06112, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_1.best.hdf5
# Epoch 2/20
# 127656/127656 [==============================] - 57s 449us/step - loss: 0.0568 - acc: 0.9798 - val_loss: 0.0515 - val_acc: 0.9812
#
# Epoch 00002: val_loss improved from 0.06112 to 0.05155, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_1.best.hdf5
# Epoch 3/20
# 127656/127656 [==============================] - 57s 450us/step - loss: 0.0515 - acc: 0.9814 - val_loss: 0.0487 - val_acc: 0.9819
#
# Epoch 00003: val_loss improved from 0.05155 to 0.04866, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_1.best.hdf5
# Epoch 4/20
# 127656/127656 [==============================] - 58s 451us/step - loss: 0.0491 - acc: 0.9821 - val_loss: 0.0478 - val_acc: 0.9822
#
# Epoch 00004: val_loss improved from 0.04866 to 0.04780, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_1.best.hdf5
# Epoch 5/20
# 127656/127656 [==============================] - 58s 452us/step - loss: 0.0471 - acc: 0.9826 - val_loss: 0.0472 - val_acc: 0.9824
#
# Epoch 00005: val_loss improved from 0.04780 to 0.04718, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_1.best.hdf5
# Epoch 6/20
# 127656/127656 [==============================] - 56s 439us/step - loss: 0.0453 - acc: 0.9832 - val_loss: 0.0456 - val_acc: 0.9829
#
# Epoch 00006: val_loss improved from 0.04718 to 0.04564, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_1.best.hdf5
# Epoch 7/20
# 127656/127656 [==============================] - 51s 397us/step - loss: 0.0440 - acc: 0.9834 - val_loss: 0.0454 - val_acc: 0.9827
#
# Epoch 00007: val_loss improved from 0.04564 to 0.04536, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_1.best.hdf5
# Epoch 8/20
# 127656/127656 [==============================] - 52s 408us/step - loss: 0.0426 - acc: 0.9837 - val_loss: 0.0452 - val_acc: 0.9828
#
# Epoch 00008: val_loss improved from 0.04536 to 0.04521, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_1.best.hdf5
# Epoch 9/20
# 127656/127656 [==============================] - 53s 417us/step - loss: 0.0412 - acc: 0.9843 - val_loss: 0.0443 - val_acc: 0.9833
#
# Epoch 00009: val_loss improved from 0.04521 to 0.04430, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_1.best.hdf5
# Epoch 10/20
# 127656/127656 [==============================] - 53s 414us/step - loss: 0.0398 - acc: 0.9846 - val_loss: 0.0457 - val_acc: 0.9830
#
# Epoch 00010: val_loss did not improve
# Epoch 11/20
# 127656/127656 [==============================] - 53s 414us/step - loss: 0.0390 - acc: 0.9849 - val_loss: 0.0437 - val_acc: 0.9837
#
# Epoch 00011: val_loss improved from 0.04430 to 0.04365, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_1.best.hdf5
# Epoch 12/20
# 127656/127656 [==============================] - 53s 414us/step - loss: 0.0377 - acc: 0.9854 - val_loss: 0.0456 - val_acc: 0.9832
#
# Epoch 00012: val_loss did not improve
# Epoch 13/20
# 127656/127656 [==============================] - 53s 414us/step - loss: 0.0368 - acc: 0.9857 - val_loss: 0.0450 - val_acc: 0.9834
#
# Epoch 00013: val_loss did not improve
# Epoch 14/20
# 127656/127656 [==============================] - 53s 414us/step - loss: 0.0360 - acc: 0.9858 - val_loss: 0.0463 - val_acc: 0.9834
#
# Epoch 00014: val_loss did not improve
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/20
# 127657/127657 [==============================] - 54s 424us/step - loss: 0.1449 - acc: 0.9539 - val_loss: 0.0628 - val_acc: 0.9786
#
# Epoch 00001: val_loss improved from inf to 0.06278, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_2.best.hdf5
# Epoch 2/20
# 127657/127657 [==============================] - 53s 415us/step - loss: 0.0579 - acc: 0.9796 - val_loss: 0.0506 - val_acc: 0.9813
#
# Epoch 00002: val_loss improved from 0.06278 to 0.05065, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_2.best.hdf5
# Epoch 3/20
# 127657/127657 [==============================] - 53s 415us/step - loss: 0.0517 - acc: 0.9811 - val_loss: 0.0477 - val_acc: 0.9824
#
# Epoch 00003: val_loss improved from 0.05065 to 0.04766, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_2.best.hdf5
# Epoch 4/20
# 127657/127657 [==============================] - 53s 416us/step - loss: 0.0489 - acc: 0.9820 - val_loss: 0.0458 - val_acc: 0.9831
#
# Epoch 00004: val_loss improved from 0.04766 to 0.04584, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_2.best.hdf5
# Epoch 5/20
# 127657/127657 [==============================] - 53s 415us/step - loss: 0.0470 - acc: 0.9826 - val_loss: 0.0446 - val_acc: 0.9834
#
# Epoch 00005: val_loss improved from 0.04584 to 0.04460, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_2.best.hdf5
# Epoch 6/20
# 127657/127657 [==============================] - 53s 416us/step - loss: 0.0453 - acc: 0.9832 - val_loss: 0.0444 - val_acc: 0.9836
#
# Epoch 00006: val_loss improved from 0.04460 to 0.04441, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_2.best.hdf5
# Epoch 7/20
# 127657/127657 [==============================] - 53s 414us/step - loss: 0.0439 - acc: 0.9835 - val_loss: 0.0442 - val_acc: 0.9838
#
# Epoch 00007: val_loss improved from 0.04441 to 0.04420, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_2.best.hdf5
# Epoch 8/20
# 127657/127657 [==============================] - 53s 416us/step - loss: 0.0428 - acc: 0.9837 - val_loss: 0.0434 - val_acc: 0.9838
#
# Epoch 00008: val_loss improved from 0.04420 to 0.04343, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_2.best.hdf5
# Epoch 9/20
# 127657/127657 [==============================] - 53s 416us/step - loss: 0.0417 - acc: 0.9840 - val_loss: 0.0425 - val_acc: 0.9838
#
# Epoch 00009: val_loss improved from 0.04343 to 0.04254, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_2.best.hdf5
# Epoch 10/20
# 127657/127657 [==============================] - 53s 417us/step - loss: 0.0406 - acc: 0.9844 - val_loss: 0.0427 - val_acc: 0.9838
#
# Epoch 00010: val_loss did not improve
# Epoch 11/20
# 127657/127657 [==============================] - 53s 415us/step - loss: 0.0392 - acc: 0.9848 - val_loss: 0.0420 - val_acc: 0.9842
#
# Epoch 00011: val_loss improved from 0.04254 to 0.04202, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_2.best.hdf5
# Epoch 12/20
# 127657/127657 [==============================] - 53s 415us/step - loss: 0.0383 - acc: 0.9851 - val_loss: 0.0424 - val_acc: 0.9841
#
# Epoch 00012: val_loss did not improve
# Epoch 13/20
# 127657/127657 [==============================] - 53s 415us/step - loss: 0.0373 - acc: 0.9854 - val_loss: 0.0440 - val_acc: 0.9841
#
# Epoch 00013: val_loss did not improve
# Epoch 14/20
# 127657/127657 [==============================] - 53s 415us/step - loss: 0.0362 - acc: 0.9858 - val_loss: 0.0424 - val_acc: 0.9840
#
# Epoch 00014: val_loss did not improve
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/20
# 127657/127657 [==============================] - 54s 422us/step - loss: 0.1329 - acc: 0.9580 - val_loss: 0.0577 - val_acc: 0.9797
#
# Epoch 00001: val_loss improved from inf to 0.05766, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_3.best.hdf5
# Epoch 2/20
# 127657/127657 [==============================] - 53s 412us/step - loss: 0.0562 - acc: 0.9800 - val_loss: 0.0501 - val_acc: 0.9817
#
# Epoch 00002: val_loss improved from 0.05766 to 0.05014, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_3.best.hdf5
# Epoch 3/20
# 127657/127657 [==============================] - 52s 411us/step - loss: 0.0512 - acc: 0.9815 - val_loss: 0.0482 - val_acc: 0.9828
#
# Epoch 00003: val_loss improved from 0.05014 to 0.04825, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_3.best.hdf5
# Epoch 4/20
# 127657/127657 [==============================] - 53s 411us/step - loss: 0.0487 - acc: 0.9821 - val_loss: 0.0480 - val_acc: 0.9826
#
# Epoch 00004: val_loss improved from 0.04825 to 0.04796, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_3.best.hdf5
# Epoch 5/20
# 127657/127657 [==============================] - 53s 412us/step - loss: 0.0465 - acc: 0.9826 - val_loss: 0.0459 - val_acc: 0.9832
#
# Epoch 00005: val_loss improved from 0.04796 to 0.04595, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_3.best.hdf5
# Epoch 6/20
# 127657/127657 [==============================] - 52s 410us/step - loss: 0.0451 - acc: 0.9830 - val_loss: 0.0451 - val_acc: 0.9838
#
# Epoch 00006: val_loss improved from 0.04595 to 0.04509, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_3.best.hdf5
# Epoch 7/20
# 127657/127657 [==============================] - 52s 411us/step - loss: 0.0436 - acc: 0.9835 - val_loss: 0.0457 - val_acc: 0.9835
#
# Epoch 00007: val_loss did not improve
# Epoch 8/20
# 127657/127657 [==============================] - 53s 411us/step - loss: 0.0425 - acc: 0.9838 - val_loss: 0.0444 - val_acc: 0.9835
#
# Epoch 00008: val_loss improved from 0.04509 to 0.04438, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_3.best.hdf5
# Epoch 9/20
# 127657/127657 [==============================] - 53s 412us/step - loss: 0.0412 - acc: 0.9840 - val_loss: 0.0450 - val_acc: 0.9835
#
# Epoch 00009: val_loss did not improve
# Epoch 10/20
# 127657/127657 [==============================] - 53s 418us/step - loss: 0.0403 - acc: 0.9845 - val_loss: 0.0448 - val_acc: 0.9836
#
# Epoch 00010: val_loss did not improve
# Epoch 11/20
# 127657/127657 [==============================] - 53s 417us/step - loss: 0.0391 - acc: 0.9847 - val_loss: 0.0446 - val_acc: 0.9834
#
# Epoch 00011: val_loss did not improve
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/20
# 127657/127657 [==============================] - 54s 426us/step - loss: 0.1319 - acc: 0.9588 - val_loss: 0.0597 - val_acc: 0.9790
#
# Epoch 00001: val_loss improved from inf to 0.05971, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_4.best.hdf5
# Epoch 2/20
# 127657/127657 [==============================] - 53s 415us/step - loss: 0.0567 - acc: 0.9799 - val_loss: 0.0508 - val_acc: 0.9810
#
# Epoch 00002: val_loss improved from 0.05971 to 0.05083, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_4.best.hdf5
# Epoch 3/20
# 127657/127657 [==============================] - 53s 416us/step - loss: 0.0512 - acc: 0.9815 - val_loss: 0.0483 - val_acc: 0.9820
#
# Epoch 00003: val_loss improved from 0.05083 to 0.04829, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_4.best.hdf5
# Epoch 4/20
# 127657/127657 [==============================] - 53s 415us/step - loss: 0.0489 - acc: 0.9821 - val_loss: 0.0484 - val_acc: 0.9821
#
# Epoch 00004: val_loss did not improve
# Epoch 5/20
# 127657/127657 [==============================] - 53s 417us/step - loss: 0.0470 - acc: 0.9826 - val_loss: 0.0466 - val_acc: 0.9824
#
# Epoch 00005: val_loss improved from 0.04829 to 0.04661, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_4.best.hdf5
# Epoch 6/20
# 127657/127657 [==============================] - 53s 416us/step - loss: 0.0453 - acc: 0.9831 - val_loss: 0.0455 - val_acc: 0.9830
#
# Epoch 00006: val_loss improved from 0.04661 to 0.04550, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_4.best.hdf5
# Epoch 7/20
# 127657/127657 [==============================] - 53s 418us/step - loss: 0.0440 - acc: 0.9836 - val_loss: 0.0453 - val_acc: 0.9830
#
# Epoch 00007: val_loss improved from 0.04550 to 0.04531, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_4.best.hdf5
# Epoch 8/20
# 127657/127657 [==============================] - 53s 416us/step - loss: 0.0431 - acc: 0.9837 - val_loss: 0.0452 - val_acc: 0.9831
#
# Epoch 00008: val_loss improved from 0.04531 to 0.04520, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_4.best.hdf5
# Epoch 9/20
# 127657/127657 [==============================] - 53s 416us/step - loss: 0.0417 - acc: 0.9841 - val_loss: 0.0447 - val_acc: 0.9834
#
# Epoch 00009: val_loss improved from 0.04520 to 0.04472, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_4.best.hdf5
# Epoch 10/20
# 127657/127657 [==============================] - 53s 418us/step - loss: 0.0386 - acc: 0.9849 - val_loss: 0.0448 - val_acc: 0.9833
#
# Epoch 00011: val_loss improved from 0.04494 to 0.04476, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_5.best.hdf5
# Epoch 12/20
# 127657/127657 [==============================] - 53s 418us/step - loss: 0.0379 - acc: 0.9851 - val_loss: 0.0447 - val_acc: 0.9834
#
# Epoch 00012: val_loss improved from 0.04476 to 0.04469, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_fold_5.best.hdf5
# Epoch 13/20
# 127657/127657 [==============================] - 53s 419us/step - loss: 0.0368 - acc: 0.9854 - val_loss: 0.0450 - val_acc: 0.9838
#
# Epoch 00013: val_loss did not improve
# Epoch 14/20
# 127657/127657 [==============================] - 53s 419us/step - loss: 0.0357 - acc: 0.9860 - val_loss: 0.0460 - val_acc: 0.9837
#
# Epoch 00014: val_loss did not improve
# Epoch 15/20
#   4000/127657 [..............................] - ETA: 48s - loss: 0.0342 - acc: 0.9865

# %%
# %%time
batch_size = 1000
epochs = 20

model = get_model()
X_tra, X_val, y_tra, y_val = train_test_split(x_train, y_train, train_size=0.95, random_state=0)
model = get_model()
file_path=f"./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.best.hdf5"
checkpoint = ModelCheckpoint(file_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

early = EarlyStopping(monitor="val_loss", mode="min", patience=3)
callbacks_list = [checkpoint, early] #earlyist = model.fit(X_tra, y_tra, batch_size=batch_size, epochs=epochs, callbacks=callbacks_list, validation_data=(X_test, y_test))
hist = model.fit(X_tra, y_tra, batch_size=batch_size, epochs=epochs, callbacks=callbacks_list, validation_data=(X_val, y_val), verbose=2)

model.load_weights(file_path)
y_pred = model.predict(x_test, batch_size=1024)
submission[["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]] = y_pred
submission.to_csv('./submits/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.csv', index=False)
# Out:
# Train on 151592 samples, validate on 7979 samples
# Epoch 1/20
#  - 57s - loss: 0.2082 - acc: 0.9316 - val_loss: 0.1370 - val_acc: 0.9634
#
# Epoch 00001: val_loss improved from inf to 0.13705, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.best.hdf5
# Epoch 2/20
#  - 56s - loss: 0.1263 - acc: 0.9639 - val_loss: 0.0824 - val_acc: 0.9706
#
# Epoch 00002: val_loss improved from 0.13705 to 0.08236, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.best.hdf5
# Epoch 3/20
#  - 56s - loss: 0.0738 - acc: 0.9750 - val_loss: 0.0567 - val_acc: 0.9806
#
# Epoch 00003: val_loss improved from 0.08236 to 0.05666, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.best.hdf5
# Epoch 4/20
#  - 56s - loss: 0.0606 - acc: 0.9789 - val_loss: 0.0515 - val_acc: 0.9816
#
# Epoch 00004: val_loss improved from 0.05666 to 0.05149, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.best.hdf5
# Epoch 5/20
#  - 56s - loss: 0.0566 - acc: 0.9800 - val_loss: 0.0494 - val_acc: 0.9820
#
# Epoch 00005: val_loss improved from 0.05149 to 0.04935, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.best.hdf5
# Epoch 6/20
#  - 56s - loss: 0.0545 - acc: 0.9806 - val_loss: 0.0477 - val_acc: 0.9821
#
# Epoch 00006: val_loss improved from 0.04935 to 0.04775, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.best.hdf5
# Epoch 7/20
#  - 56s - loss: 0.0531 - acc: 0.9810 - val_loss: 0.0466 - val_acc: 0.9827
#
# Epoch 00007: val_loss improved from 0.04775 to 0.04664, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.best.hdf5
# Epoch 8/20
#  - 56s - loss: 0.0521 - acc: 0.9813 - val_loss: 0.0463 - val_acc: 0.9825
#
# Epoch 00008: val_loss improved from 0.04664 to 0.04629, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.best.hdf5
# Epoch 9/20
#  - 56s - loss: 0.0511 - acc: 0.9814 - val_loss: 0.0457 - val_acc: 0.9828
#
# Epoch 00009: val_loss improved from 0.04629 to 0.04573, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.best.hdf5
# Epoch 10/20
#  - 56s - loss: 0.0505 - acc: 0.9814 - val_loss: 0.0451 - val_acc: 0.9828
#
# Epoch 00010: val_loss improved from 0.04573 to 0.04506, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.best.hdf5
# Epoch 11/20
#  - 56s - loss: 0.0497 - acc: 0.9819 - val_loss: 0.0448 - val_acc: 0.9830
#
# Epoch 00011: val_loss improved from 0.04506 to 0.04482, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.best.hdf5
# Epoch 12/20
#  - 56s - loss: 0.0492 - acc: 0.9819 - val_loss: 0.0447 - val_acc: 0.9832
#
# Epoch 00012: val_loss improved from 0.04482 to 0.04466, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.best.hdf5
# Epoch 13/20
#  - 56s - loss: 0.0488 - acc: 0.9821 - val_loss: 0.0442 - val_acc: 0.9834
#
# Epoch 00013: val_loss improved from 0.04466 to 0.04419, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.best.hdf5
# Epoch 14/20
#  - 57s - loss: 0.0480 - acc: 0.9822 - val_loss: 0.0437 - val_acc: 0.9836
#
# Epoch 00014: val_loss improved from 0.04419 to 0.04367, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.best.hdf5
# Epoch 15/20
#  - 57s - loss: 0.0479 - acc: 0.9822 - val_loss: 0.0432 - val_acc: 0.9837
#
# Epoch 00015: val_loss improved from 0.04367 to 0.04325, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.best.hdf5
# Epoch 16/20
#  - 56s - loss: 0.0471 - acc: 0.9827 - val_loss: 0.0432 - val_acc: 0.9835
#
# Epoch 00016: val_loss improved from 0.04325 to 0.04318, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.best.hdf5
# Epoch 17/20
#  - 56s - loss: 0.0468 - acc: 0.9827 - val_loss: 0.0427 - val_acc: 0.9837
#
# Epoch 00017: val_loss improved from 0.04318 to 0.04269, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.best.hdf5
# Epoch 18/20
#  - 56s - loss: 0.0463 - acc: 0.9827 - val_loss: 0.0425 - val_acc: 0.9838
#
# Epoch 00018: val_loss improved from 0.04269 to 0.04254, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.best.hdf5
# Epoch 19/20
#  - 56s - loss: 0.0458 - acc: 0.9829 - val_loss: 0.0423 - val_acc: 0.9840
#
# Epoch 00019: val_loss improved from 0.04254 to 0.04233, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.best.hdf5
# Epoch 20/20
#  - 56s - loss: 0.0454 - acc: 0.9830 - val_loss: 0.0421 - val_acc: 0.9840
#
# Epoch 00020: val_loss improved from 0.04233 to 0.04212, saving model to ./additional_matiriels/weights_base_gru_100_0.4_200_0.5_100_0.4_layers_submit.best.hdf5
# CPU times: user 14min 53s, sys: 2min 11s, total: 17min 4s
# Wall time: 19min 8s
